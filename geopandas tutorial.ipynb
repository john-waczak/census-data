# %%
import numpy as np
import matplotlib.pyplot as plt

import geopandas as gpd
# NOTE: we also need the descartes package

# %%
path = "./test_tract/tl_2010_01_tract10/tl_2010_01_tract10.shp"

# %% [markdown]
# Read in the shape file

# %%
gdf = gpd.read_file(path)

# %%
gdf.head()
# Out:
#   STATEFP10 COUNTYFP10 TRACTCE10      GEOID10 NAME10         NAMELSAD10  \
# 0        01        005    950300  01005950300   9503  Census Tract 9503
# 1        01        005    950900  01005950900   9509  Census Tract 9509
# 2        01        005    950800  01005950800   9508  Census Tract 9508
# 3        01        005    950700  01005950700   9507  Census Tract 9507
# 4        01        005    950600  01005950600   9506  Census Tract 9506
#
#   MTFCC10 FUNCSTAT10    ALAND10  AWATER10   INTPTLAT10    INTPTLON10  \
# 0   G5020          S  352811329    499970  +31.7908933  -085.5670514
# 1   G5020          S   16201446   8339342  +31.8467221  -085.1462332
# 2   G5020          S   14630162    380622  +31.9206930  -085.1760317
# 3   G5020          S  127200997    112809  +31.9440855  -085.2620842
# 4   G5020          S  101697268   1101261  +31.8783526  -085.2729215
#
#                                             geometry
# 0  POLYGON ((-85.52744 31.86650, -85.52753 31.866...
# ...

# %%
gdf.shape
# Out:
# (1181, 13)

# %%
p1 = gdf.plot(figsize=(12,12), cmap='viridis', column = 'NAME10')

# %%
len(gdf)
# Out:
# 1181
